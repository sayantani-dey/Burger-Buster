# %%
# !pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/9b/ea/7219c01b5e92d02d2bc994a36245d99331cd66eb12d284707a2060a013d0/streamlit-1.32.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/c5/e4/7fcceef127badbb0d644d730d992410e4f3799b295c9964a172f92a469c7/altair-5.2.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/fa/2a/7f3714cbc6356a0efec525ce7a0613d581072ed6eb53eb7b9754f33db807/blinker-1.7.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
# ...

# %%
import streamlit as st
from PIL import Image, ImageOps
import tensorflow as tf
# Out:
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = tf.keras.models.load_model("C:/Users/SAYANTANI DEY/Desktop/work/Self Tasks/VSC notebook/Food Classification/foodclassifier.h5")

# Define some class labels (healthy/unhealthy or more specific categories)
class_names = ['Healthy', 'Unhealthy']
# Out:
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
def predict_food(image):
  """
  Preprocesses the image and predicts the class using your model.
  """
  # Preprocess the image (resize, normalize, etc.)
  img = ImageOps.resize(image, (224, 224))  # Assuming your model expects 224x224 image
  img = np.asarray(img)
  img = np.expand_dims(img, axis=0)  # Add a batch dimension
  img = img / 255.0  # Normalize pixel values

  # Make prediction using your model
  predictions = model.predict(img)
  predicted_class = class_names[np.argmax(predictions[0])]
  return predicted_class

st.title("Food Classification App")
st.write("Upload a food image to classify it as healthy or unhealthy.")

uploaded_file = st.file_uploader("Choose an Image", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
  image = Image.open(uploaded_file)
  st.image(image, caption="Uploaded Image")

  if st.button("Classify"):
    prediction = predict_food(image)
    st.subheader(f"Prediction: {prediction}")
# Out:
# 2024-03-22 12:03:26.392
# ...
#   command:
#
#     streamlit run D:\Anaconda\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
